# %%
import sys

# !which {sys.executable}
# Out:
# /ut3/jerome/miniconda3/envs/wakai/bin/python

# %%
import sys
sys.path.insert(0, '../code')

# %% [raw]
# %load init_ipynb

# %% [markdown]
# # Hunt+2023 catalog

# %% [markdown]
# https://ucc.ar/_clusters/ngc1039/

# %%
from catalog import CatalogDownloader

cd = CatalogDownloader(catalog_name="Hunt2023", catalog_type="cluster")
tabs = cd.get_tables_from_vizier(row_limit=-1, save=True)
# Out:
# 2025-05-15 13:47:40.594 | INFO     | catalog:get_vizier_url:1327 - Data url:
# 2025-05-15 13:47:40.595 | INFO     | catalog:get_tables_from_vizier:1279 - Downloading all tables in J/A+A/673/A114 from vizier.
# 2025-05-15 13:48:33.453 | INFO     | catalog:save_tables:1318 - Set clobber=True to overwrite.
# 2025-05-15 13:48:33.458 | INFO     | catalog:save_tables:1318 - Set clobber=True to overwrite.
# 2025-05-15 13:48:33.461 | INFO     | catalog:save_tables:1318 - Set clobber=True to overwrite.
# 2025-05-15 13:48:33.464 | INFO     | catalog:save_tables:1318 - Set clobber=True to overwrite.
# 2025-05-15 13:48:33.468 | INFO     | catalog:save_tables:1318 - Set clobber=True to overwrite.
# {'J/A+A/673/A114/clusters': 'Main catalogue (Table 3)',
#  'J/A+A/673/A114/clustrej': 'Objects rejected from main catalogue',
#  'J/A+A/673/A114/crossma': 'All (non-)xmatched clusters (Table B.1)',
#  'J/A+A/673/A114/members': 'Member stars of clusters (corrected version)',
#  'J/A+A/673/A114/membrej': 'Member stars of rejected clusters'}

# %%
df = tabs[0].to_pandas()
df_mem = tabs[1].to_pandas()
df_mem.head()
# Out:
#        Name  ID              GaiaDR3  inrt      Prob     RA_ICRS    DE_ICRS  \
# 0  1636-283   0  6032349260227596544     0  0.747692  249.708525 -28.585117
# 1  1636-283   0  6032358331198284160     1  1.000000  249.866424 -28.402037
# 2  1636-283   0  6032358331198285696     1  0.843798  249.865221 -28.399406
# 3  1636-283   0  6032358331198286080     1  1.000000  249.861159 -28.400698
# 4  1636-283   0  6032358670488486784     1  1.000000  249.939480 -28.429366
#
#     pmRA   pmDE      Plx       Gmag      BPmag      RPmag    RV    _RA.icrs  \
# 0 -1.503 -6.118  0.10850  18.573350  19.163387  17.590090   NaN  249.708532
# 1 -1.407 -6.418  0.12050  14.002328  15.070900  12.975450  16.4  249.866431
# 2 -1.430 -6.352  0.06114  16.036104  16.824158  15.149750   NaN  249.865229
# 3 -1.561 -6.447  0.11180  16.029701  16.752527  15.179749   NaN  249.861167
# 4 -1.564 -6.553  0.14850  15.495458  16.392687  14.553366   NaN  249.939488
#
#     _DE.icrs
# 0 -28.585090
# 1 -28.402009
# 2 -28.399378
# 3 -28.400669
# 4 -28.429337

# %%
#replace name to be compatible with other catalogs' naming formats
df_mem = df_mem.rename({"name": "Name",
                        "Source": "GaiaDR3",
                        "probs": "Prob",
                        "RA_ICRS": "ra",
                        "DE_ICRS": "dec",
                        "pmRA": "pmra",
                        "pmDE": "pmdec",
                        "Plx": "parallax",
                        "RV": "radial_velocity"
                        }, axis=1)
df_mem
# Out:
#                Name    ID              GaiaDR3  inrt      Prob          ra  \
# 0          1636-283     0  6032349260227596544     0  0.747692  249.708525
# 1          1636-283     0  6032358331198284160     1  1.000000  249.866424
# 2          1636-283     0  6032358331198285696     1  0.843798  249.865221
# 3          1636-283     0  6032358331198286080     1  1.000000  249.861159
# 4          1636-283     0  6032358670488486784     1  1.000000  249.939480
# ...             ...   ...                  ...   ...       ...         ...
# 1291924  vdBergh_92  7163  3045840104515988992     1  1.000000  106.116546
# 1291925  vdBergh_92  7163  3045840074455065088     1  0.838193  106.136236
# 1291926  vdBergh_92  7163  3045840074453671680     1  0.639341  106.135606
# 1291927  vdBergh_92  7163  3045840654267074048     1  0.738133  106.159649
# 1291928  vdBergh_92  7163  3046211537585833984     1  0.811015  106.285883
#
#                dec   pmra  pmdec  parallax       Gmag      BPmag      RPmag  \
# 0       -28.585117 -1.503 -6.118   0.10850  18.573350  19.163387  17.590090
# 1       -28.402037 -1.407 -6.418   0.12050  14.002328  15.070900  12.975450
# 2       -28.399406 -1.430 -6.352   0.06114  16.036104  16.824158  15.149750
# 3       -28.400698 -1.561 -6.447   0.11180  16.029701  16.752527  15.179749
# 4       -28.429366 -1.564 -6.553   0.14850  15.495458  16.392687  14.553366
# ...            ...    ...    ...       ...        ...        ...        ...
# 1291924 -11.474387 -4.446  1.700   0.84190  18.107680  19.282660  16.973217
# 1291925 -11.471452 -4.228  1.542   0.93000  16.596190  17.493513  15.584210
# 1291926 -11.468653 -4.165  1.551   0.78650  16.886219  17.950207  15.875672
# 1291927 -11.436082 -4.158  1.572   0.97190  16.914060  17.826698  15.848995
# 1291928 -11.502450 -4.120  1.642   0.84690  12.033337  12.243465  11.677808
#
#          radial_velocity    _RA.icrs   _DE.icrs
# 0                    NaN  249.708532 -28.585090
# 1                  16.40  249.866431 -28.402009
# 2                    NaN  249.865229 -28.399378
# 3                    NaN  249.861167 -28.400669
# 4                    NaN  249.939488 -28.429337
# ...                  ...         ...        ...
# 1291924              NaN  106.116566 -11.474394
# 1291925              NaN  106.136255 -11.471459
# 1291926              NaN  106.135625 -11.468660
# 1291927              NaN  106.159667 -11.436089
# 1291928             3.05  106.285902 -11.502458
#
# [1291929 rows x 16 columns]

# %%
from catalog import get_tois

tois = get_tois()
# tois.columns.tolist()

# %%
tois[tois.Comments.apply(lambda x: 'young' in str(x))]
# Out:
#          TIC ID      TOI     Previous CTOI  Master  SG1A  SG1B  SG2  SG3  SG4  \
# 730   146520535   942.01               NaN       3     5     5    3    4    4
# 2855  330135981  3604.01               NaN       3     4     4    3    2    4
# 4833  308300731  5743.01               NaN       3     4     3    3    4    4
# 5025  236785891  5956.01  TIC 236785891.01       3     4     4    3    2    4
# 5311  435878153  6258.01               NaN       2     4     4    2    4    4
# 5726  253864764  6678.01               NaN       1     4     1    1    3    4
#
#       SG5  ...  Stellar Mass (M_Sun) err      Sectors  Date TOI Alerted (UTC)  \
# 730     4  ...                  0.097250            5              2019-07-24
# 2855    4  ...                       NaN  16,17,56,57              2021-06-23
# 4833    4  ...                  0.109025  26,53,79,80              2022-09-01
# 5025    4  ...                  0.021842        56,57              2022-11-16
# 5311    4  ...                  0.020209        17,57              2023-04-06
# 5726    4  ...                  0.092773           67              2023-09-21
#
#       Date TOI Updated (UTC)        Date Modified  \
# 730               2020-05-20  2022-12-14 12:09:24
# 2855              2024-09-06  2024-09-06 00:00:00
# 4833              2024-08-25  2024-08-31 12:14:55
# 5025              2023-02-03  2024-09-01 00:00:00
# 5311              2023-04-06  2024-02-23 00:00:00
# 5726              2023-09-21  2024-09-12 00:00:00
#
#                                                Comments      ra_deg  \
# 730   Probable young K dwarf. Transit is believable ...   76.649625
# 2855  V-shaped; found in faint-star QLP search; no s...  333.501042
# 4833  radius possibly underestimated; potentially yo...  267.904333
# 5025  V-shaped; large; young host star; ~5 sigma odd...  283.317250
# 5311  low SNR; asymmetric transit shape; flaring pos...   13.085375
# 5726  rotational modulation at 7-8 days may indicate...  283.536292
#
#         dec_deg  GaiaDR3_exofop  GaiaDR3_vizier
# 730  -20.245614    2.974907e+18    2.974907e+18
# 2855  56.918981    2.198435e+18    2.198435e+18
# 4833  24.427456    4.581034e+18    4.581034e+18
# 5025  59.817658    2.155491e+18    2.155491e+18
# 5311  20.938875    2.789799e+18    2.789799e+18
# 5726 -36.656858    6.731034e+18    6.731034e+18
#
# [6 rows x 66 columns]

# %% [markdown]
# # cross-match TOI with catalog

# %%
import pandas as pd

if True:
    #from astroquery.xmatch
    matches = pd.read_csv('../data/TOIs_GaiaDR3_xmatch.csv')
if False:
    #from vizier query/exofop
    matches = pd.read_csv('../data/TOIs_with_Gaiaid.csv')
    matches['GaiaDR3'] = matches['GaiaDR3_vizier']
matches.tail()
# Out:
#        angDist     TIC ID      TOI Previous CTOI  Master  SG1A  SG1B  SG2  \
# 7740  0.079164  259381479  7451.01           NaN       3     4     3    3
# 7741  0.006298  327249454  7452.01           NaN       3     4     3    3
# 7742  0.012678  347944406  7453.01           NaN       3     4     3    3
# 7743  0.025960  130087198  7454.01           NaN       3     4     3    3
# 7744  0.045442  196351790  7455.01           NaN       3     4     3    3
#
#       SG3  SG4  ...  E(BP-RP)  b_E(BP-RP)  B_E(BP-RP)      Lib    RAJ2000  \
# 7740    1    4  ...       NaN         NaN         NaN      NaN  43.399531
# 7741    1    4  ...    0.4886      0.4849      0.4927        A   3.511682
# 7742    1    4  ...       NaN         NaN         NaN      NaN  34.003481
# 7743    1    4  ...    0.0495      0.0444      0.0553    MARCS  37.777380
# 7744    1    4  ...    0.0049      0.0015      0.0192  PHOENIX  14.410832
#
#         DEJ2000  e_RAJ2000 e_DEJ2000 RADEcorJ2000             GaiaDR3
# 7740  46.174566   0.595016  0.648654       0.2903  434019879918762112
# 7741  58.167092   0.227478  0.218697      -0.4282  422831666214648448
# 7742  57.346115   0.171583  0.213738       0.1890  458577476430838272
# 7743  40.724970   0.336897  0.297551       0.0898  338358386869541632
# 7744  47.522054   0.251246  0.213116      -0.0815  402047872787248512
#
# [5 rows x 205 columns]

# %%
final = pd.merge(df_mem, matches, on='GaiaDR3')
final.head()
# Out:
#         Name   ID              GaiaDR3  inrt      Prob          ra        dec  \
# 0  Alessi_13   76  4860787013426321664     1  1.000000   52.647359 -35.203716
# 1   Alessi_3   69  5510676828723793920     1  1.000000  110.369673 -45.567736
# 2  Alessi_37   87  1984154395449640832     1  1.000000  342.410629  46.349983
# 3  Alessi_37   87  1983367454361525888     1  0.626075  338.883370  45.834178
# 4  CWNU_1012  564  6818415476100569088     1  1.000000  326.272748 -20.032513
#
#         pmra   pmdec  parallax  ...    B_AG  E(BP-RP)  b_E(BP-RP)  B_E(BP-RP)  \
# 0  35.720001  -4.416     9.434  ...  0.7293    0.4921      0.4895      0.4946
# 1  -9.754000  11.490     3.537  ...  0.1155    0.0439      0.0353      0.0622
# 2   0.353500  -1.535     1.395  ...     NaN       NaN         NaN         NaN
# 3  -0.084040  -1.751     1.360  ...  0.4672    0.2504      0.2482      0.2527
# 4  13.180000   1.331     3.633  ...  0.1988    0.1036      0.1006      0.1064
#
#        Lib     RAJ2000    DEJ2000  e_RAJ2000  e_DEJ2000 RADEcorJ2000
# 0    MARCS   52.647165 -35.203696   0.327464   0.453024      -0.2442
# 1    MARCS  110.369735 -45.567787   0.233057   0.281628      -0.0054
# 2      NaN  342.410626  46.349990   0.160795   0.159302      -0.2545
# 3  PHOENIX  338.883371  45.834186   0.211234   0.201389      -0.3375
# 4  PHOENIX  326.272685 -20.032519   1.427530   1.178623       0.4734
#
# [5 rows x 220 columns]

# %%
new_cols = "TOI	TIC ID	Name	GaiaDR3	Prob	TESS Disposition	TFOPWG Disposition	Comments	TESS Mag	TESS Mag err	Source_1	Detection	Epoch (BJD)	Epoch (BJD) err	Period (days)	Period (days) err	Duration (hours)	Duration (hours) err	Depth (mmag)	Depth (mmag) err	Depth (ppm)	Depth (ppm) err	Planet Radius (R_Earth)	Planet Radius (R_Earth) err	Planet Insolation (Earth Flux)	Planet Equil Temp (K)	Planet SNR	Stellar Distance (pc)	Stellar Distance (pc) err	Stellar Eff Temp (K)	Stellar Eff Temp (K) err	Stellar log(g) (cm/s^2)	Stellar log(g) (cm/s^2) err	Stellar Radius (R_Sun)	Stellar Radius (R_Sun) err	Stellar Metallicity	Stellar Metallicity err	Stellar Mass (M_Sun)	Stellar Mass (M_Sun) err	Sectors	Date TOI Alerted (UTC)	Date TOI Updated (UTC)	Date Modified	ra_deg	dec_deg	Pipeline Signal ID	RA	Dec	PM RA (mas/yr)	PM RA err (mas/yr)	PM Dec (mas/yr)	PM Dec err (mas/yr)	DR3Name	RAdeg	DEdeg	errHalfMaj	errHalfMin	errPosAng	SolID	Source_2	RandomI	e_RAdeg	e_DEdeg	RPlx	PM	RADEcor	RAPlxcor	RApmRAcor	RApmDEcor	DEPlxcor	DEpmRAcor	DEpmDEcor	PlxpmRAcor	PlxpmDEcor	pmRApmDEcor	NAL	NAC	NgAL	NbAL	gofAL	chi2AL	epsi	sepsi	Solved	APF	nueff	MatchObsA	Nper	amax	MatchObs	IPDgofha	IPDgofhp	IPDfmp	IPDfow	RUWE	Dup	o_Gmag	FG	e_FG	RFG	Gmag_y	o_BPmag	FBP	e_FBP	RFBP	e_BPmag	o_RPmag	FRP	e_FRP	RFRP	e_RPmag	E(BP/RP)	NBPcont	NBPblend	NRPcont	NRPblend	Mode	BP-G	G-RP	n_RV	o_RV	o_RVd	RVNper	RVS/N	RVgof	RVchi2	RVTdur	RVamp	RVtempTeff	RVtemplogg	RVtemp[Fe/H]	Vatmparam	vbroad	e_Vbroad	o_Vbroad	GRVSmag	e_GRVSmag	o_GRVSmag	RVSS/N	VarFlag	PQSO	PGal	PSS	Teff	b_Teff	B_Teff	logg	b_logg	B_logg	[Fe/H]	b_[Fe/H]	B_[Fe/H]	Dist	b_Dist	B_Dist	A0	b_A0	B_A0	AG	b_AG	B_AG	E(BP-RP)	b_E(BP-RP)	B_E(BP-RP)	Lib	RAJ2000	DEJ2000	e_RAJ2000	e_DEJ2000	RADEcorJ2000	Previous CTOI	Master	SG1A	SG1B	SG2	SG3	SG4	SG5	ESM	TSM	Predicted Mass (M_Earth)	Time Series Observations	Spectroscopy Observations	Imaging Observations".split('\t')

# %%
final[new_cols].sort_values(by='TOI', ascending=False).head()
# Out:
#         TOI     TIC ID       Name              GaiaDR3      Prob  \
# 3   7111.01  200465781  Alessi_37  1983367454361525888  0.626075
# 24  7038.01  210904767   HSC_2907  6025147218543620480  0.757498
# 7   6963.01   56658270  CWNU_1129   164800235906366976  1.000000
# 28  6715.01  460950389    IC_2602  5239758155778687360  0.737033
# 23  6705.01  379717270   HSC_2675  5895008644342480640  1.000000
#
#    TESS Disposition TFOPWG Disposition  \
# 3                PC                 PC
# 24               PC                 PC
# 7                PC                 CP
# 28               PC                 PC
# 23               PC                 PC
#
#                                    Comments  TESS Mag  TESS Mag err  ... SG2  \
# 3            found in faint-star QLP search   12.9436         0.012  ...   3
# 24                            variable host    8.9498         0.006  ...   4
# 7                              T Tauri host   12.8131         0.007  ...   3
# 28  host is a BY Dra variable star; low MES   11.6490         0.006  ...   2
# 23   variable host; multiple stars in pixel   10.2734         0.006  ...   3
#
#    SG3  SG4  SG5   ESM   TSM  Predicted Mass (M_Earth)  \
# 3    1    4    4  12.5  46.2                     87.78
# 24   1    4    4   4.3  49.8                      9.97
# 7    4    4    4  21.8  54.2                     60.85
# 28   3    4    4  10.8  67.3                     14.54
# 23   1    4    4  56.8  86.0                    317.00
#
#     Time Series Observations  Spectroscopy Observations  Imaging Observations
# 3                          0                          0                     0
# 24                         0                          2                     0
# 7                          4                          0                     0
# 28                         3                          3                     4
# 23                         3                          0                     0
#
# [5 rows x 184 columns]

# %%
final[new_cols].to_csv(f'../data/{cd.catalog_name}/TOIs_in_{cd.catalog_name}.csv', index=False)
